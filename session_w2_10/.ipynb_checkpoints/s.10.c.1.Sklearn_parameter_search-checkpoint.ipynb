# %%
# !pwd
# !cd /home/ubuntu/Berend_Gort/session_9
# !pwd
# Out:
# /home/ubuntu/Berend_Gort/session_10
# /home/ubuntu/Berend_Gort/session_10

# %%
import pandas as pd
import numpy as np

from sklearn import model_selection

# %% [markdown]
# ## Parameters search

# %%
titanic_df = pd.read_csv('titanic.csv')

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(
    titanic_df.drop('Survived', axis=1),
    titanic_df['Survived'])

# %%
X_train
# Out:
#      PassengerId  Pclass                                               Name  \
# 16            17       3                               Rice, Master. Eugene
# 239          240       2                             Hunt, Mr. George Henry
# 377          378       1                          Widener, Mr. Harry Elkins
# 162          163       3                         Bengtsson, Mr. John Viktor
# 256          257       1                     Thorne, Mrs. Gertrude Maybelle
# ..           ...     ...                                                ...
# 148          149       2           Navratil, Mr. Michel ("Louis M Hoffman")
# 580          581       2                        Christy, Miss. Julie Rachel
# 618          619       2                        Becker, Miss. Marion Louise
# 630          631       1               Barkworth, Mr. Algernon Henry Wilson
# 334          335       1  Frauenthal, Mrs. Henry William (Clara Heinshei...
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 16     male   2.0      4      1      382652   29.125   NaN        Q
# 239    male  33.0      0      0  SCO/W 1585   12.275   NaN        S
# 377    male  27.0      0      2      113503  211.500   C82        C
# 162    male  26.0      0      0      347068    7.775   NaN        S
# 256  female   NaN      0      0    PC 17585   79.200   NaN        C
# ..      ...   ...    ...    ...         ...      ...   ...      ...
# 148    male  36.5      0      2      230080   26.000    F2        S
# 580  female  25.0      1      1      237789   30.000   NaN        S
# 618  female   4.0      2      1      230136   39.000    F4        S
# 630    male  80.0      0      0       27042   30.000   A23        S
# 334  female   NaN      1      0    PC 17611  133.650   NaN        S
#
# [668 rows x 11 columns]

# %%
# %store X_train
# Out:
# Stored 'X_train' (DataFrame)

# %% [markdown]
# #### for classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
classifier = RandomForestClassifier(n_estimators=300, random_state=0)

# %%
grid_param = {
    'n_estimators': [100, 300, 500, 800, 1000],
    'criterion': ['gini', 'entropy'],
    'bootstrap': [True, False],
    'max_depth': [1,2,3,6, None]
}

# %%
from sklearn import model_selection

# %% [markdown]
# ### Grid Search

# %%
grid_search_classifier = model_selection.GridSearchCV(estimator=classifier,
                     param_grid=grid_param,
                     scoring='accuracy',
                     cv=5,
                     n_jobs=-1)
grid_search_classifier
# Out:
# GridSearchCV(cv=5,
#              estimator=RandomForestClassifier(n_estimators=300, random_state=0),
#              n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'criterion': ['gini', 'entropy'],
#                          'max_depth': [1, 2, 3, 6, None],
#                          'n_estimators': [100, 300, 500, 800, 1000]},
#              scoring='accuracy')

# %%
# %%time
grid_search_classifier.fit(X_train[ ['Pclass', 'SibSp','Fare' ] ], y_train)
# Out:
# CPU times: user 3.39 s, sys: 181 ms, total: 3.57 s
# Wall time: 50.9 s
# GridSearchCV(cv=5,
#              estimator=RandomForestClassifier(n_estimators=300, random_state=0),
#              n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'criterion': ['gini', 'entropy'],
#                          'max_depth': [1, 2, 3, 6, None],
#                          'n_estimators': [100, 300, 500, 800, 1000]},
#              scoring='accuracy')

# %%
best_parameters = grid_search_classifier.best_params_
print(best_parameters)
# Out:
# {'bootstrap': True, 'criterion': 'gini', 'max_depth': 6, 'n_estimators': 1000}

# %%
grid_search_classifier.best_score_
# Out:
# 0.7365278868813826

# %%
grid_search_classifier.cv_results_
# Out:
# {'mean_fit_time': array([0
#         0.01022297, 0.01022297, 0.01022297, 0.01022297, 0.01022297,
#         0.00855625, 0.00629632, 0.00629632, 0.00723655, 0.00629632,
#         0.01720041, 0.01720041, 0.01720041, 0.01720041, 0.01772324]),
#  'rank_test_score': array([41, 52, 58, 48, 42, 35, 39, 35, 30, 33, 40, 35, 23, 23, 23, 19,  5,
#          3,  2,  1, 90, 78, 59, 85, 71, 71, 88, 49, 50, 50, 35, 34, 30, 21,
#         22, 30, 23, 23, 23, 23,  9,  6, 20,  4,  8, 87, 74, 59, 85, 73, 93,
#         93, 91, 93, 93, 61, 61, 61, 61, 61, 43, 43, 43, 43, 43, 13, 18, 14,
#         14, 14, 89, 79, 79, 75, 75, 93, 93, 91, 93, 93, 61, 61, 61, 61, 61,
#         53, 53, 53, 53, 53,  6, 10, 10, 17, 10, 79, 79, 79, 79, 75],
#        dtype=int32)}

# %%
len(grid_search_classifier.cv_results_['params'])
# Out:
# 100

# %% [markdown]
# ### Random search

# %%
random_search_classifier = model_selection.RandomizedSearchCV(estimator=classifier,
                     param_distributions = grid_param,
                     n_iter=30,
                     scoring='accuracy',
                     cv=5,
                     n_jobs=-1)

# %%
# %%time
random_search_classifier.fit(X_train[ ['Pclass', 'SibSp','Fare' ] ], y_train)
# Out:
# CPU times: user 1.67 s, sys: 23.9 ms, total: 1.69 s
# Wall time: 15.2 s
# RandomizedSearchCV(cv=5,
#                    estimator=RandomForestClassifier(n_estimators=300,
#                                                     random_state=0),
#                    n_iter=30, n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'criterion': ['gini', 'entropy'],
#                                         'max_depth': [1, 2, 3, 6, None],
#                                         'n_estimators': [100, 300, 500, 800,
#                                                          1000]},
#                    scoring='accuracy')

# %%
best_parameters = random_search_classifier.best_params_
print(best_parameters)
# Out:
# {'n_estimators': 800, 'max_depth': 6, 'criterion': 'entropy', 'bootstrap': True}

# %%
random_search_classifier.best_score_
# Out:
# 0.7320614970261474

# %%
grid_search_classifier.cv_results_
# Out:
# {'mean_fit_time': array([0.13921189, 0.41598306, 0.67348762, 1.09310098, 1.36107669,
#         0.14288321, 0.40602245, 0.70045595, 1.07321997, 1.39814782,
#         0.14356432, 0.42611122, 0.70484209, 1.10683889, 1.34240007,
#         0.14631858, 0.43604832, 0.73504419, 1.14869065, 1.48224478,
#         0.15356631, 0.46026106, 0.77447224, 1.29990797, 1.58533454,
#         0.13385348, 0.40372043, 0.66553717, 1.08007693, 1.37927151,
#         0.13975635, 0.40890088, 0.7068181 , 1.11989579, 1.43387852,
#         0.13967605, 0.43200154, 0.72241254, 1.12763839, 1.41565714,
#         0.15882459, 0.4681807 , 0.76234984, 1.23440924, 1.46562657,
#         0.18267617, 0.50871334, 0.90235276, 1.46611619, 1.74850254,
#         0.11439166, 0.30922008, 0.51032791, 0.7868257 , 1.02355728,
#         0.10227647, 0.29997978, 0.53188696, 0.78714528, 1.0241425 ,
#         0.10410795, 0.3143991 , 0.52787056, 0.87096453, 1.03737416,
#         0.12073164, 0.3482543 , 0.56595817, 0.91051598, 1.12880588,
#         0.13271422, 0.40777035, 0.67803493, 1.07034197, 1.32712684,
#         0.10219579, 0.31095881, 0.52759848, 0.83139901, 1.01489739,
#         0.01720041, 0.01720041, 0.01720041, 0.01720041, 0.01772324]),
#  'rank_test_score': array([41, 52, 58, 48, 42, 35, 39, 35, 30, 33, 40, 35, 23, 23, 23, 19,  5,
#          3,  2,  1, 90, 78, 59, 85, 71, 71, 88, 49, 50, 50, 35, 34, 30, 21,
#         22, 30, 23, 23, 23, 23,  9,  6, 20,  4,  8, 87, 74, 59, 85, 73, 93,
#         93, 91, 93, 93, 61, 61, 61, 61, 61, 43, 43, 43, 43, 43, 13, 18, 14,
#         14, 14, 89, 79, 79, 75, 75, 93, 93, 91, 93, 93, 61, 61, 61, 61, 61,
#         53, 53, 53, 53, 53,  6, 10, 10, 17, 10, 79, 79, 79, 79, 75],
#        dtype=int32)}

# %%
from scipy import stats

# %%
best_parameters
# Out:
# {'n_estimators': 800,
#  'max_depth': 6,
#  'criterion': 'entropy',
#  'bootstrap': True}

# %%
param_distribution = {
    'n_estimators': stats.poisson(300),
    'criterion': ['gini', 'entropy'],
    'bootstrap': [True, False],
    'max_depth': stats.binom(10,0.3)
}

# %%
random_search_classifier_2 = model_selection.RandomizedSearchCV(estimator=classifier,
                     param_distributions = param_distribution,
                     n_iter=30,
                     scoring='accuracy',
                     cv=5,
                     n_jobs=-1)

# %%
# %%time
random_search_classifier_2.fit(X_train[ ['Pclass', 'SibSp','Fare' ] ], y_train)
# Out:
# CPU times: user 829 ms, sys: 42 ms, total: 871 ms
# Wall time: 7.95 s
# RandomizedSearchCV(cv=5,
#                    estimator=RandomForestClassifier(n_estimators=300,
#                                                     random_state=0),
#                    n_iter=30, n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'criterion': ['gini', 'entropy'],
#                                         'max_depth': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f71414d5c18>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f71414d5908>},
#                    scoring='accuracy')

# %%
best_parameters = random_search_classifier_2.best_params_
print(best_parameters)
# Out:
# {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'n_estimators': 281}

# %%
random_search_classifier_2.best_score_
# Out:
# 0.7350129053978229

# %% [markdown]
# #### for pipeline

# %%
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV


pca = PCA()
logistic = LogisticRegression(max_iter=10000, tol=0.1)
pipe = Pipeline(steps=[('pca', pca), ('logistic', logistic)])

# %%
X_train[ ['Pclass', 'SibSp','Fare' ] ]
# Out:
#      Pclass  SibSp     Fare
# 16        3      4   29.125
# 239       2      0   12.275
# 377       1      0  211.500
# 162       3      0    7.775
# 256       1      0   79.200
# ..      ...    ...      ...
# 148       2      0   26.000
# 580       2      1   30.000
# 618       2      2   39.000
# 630       1      0   30.000
# 334       1      1  133.650
#
# [668 rows x 3 columns]

# %%
range(2,10)
# Out:
# range(2, 10)

# %%
pipe_param_distribution = {
    'pca__n_components': range(2,11),
    'pca__svd_solver':['auto','randomized'],
    'logistic__penalty':['l2','l1'],
    'logistic__max_iter': range(700,1201)
}

# %%
random_search_pipeline = model_selection.RandomizedSearchCV(estimator=pipe,
                     param_distributions = pipe_param_distribution,
                     n_iter=10,
                     scoring='accuracy',
                     cv=5,
                     n_jobs=-1)

# %%
# %%time
random_search_pipeline.fit(X_train[ ['Pclass', 'SibSp','Fare' ] ], y_train)
# Out:
# CPU times: user 158 ms, sys: 64.2 ms, total: 222 ms
# Wall time: 159 ms
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('pca', PCA()),
#                                              ('logistic',
#                                               LogisticRegression(max_iter=10000,
#                                                                  tol=0.1))]),
#                    n_jobs=-1,
#                    param_distributions={'logistic__max_iter': range(700, 1201),
#                                         'logistic__penalty': ['l2', 'l1'],
#                                         'pca__n_components': range(2, 11),
#                                         'pca__svd_solver': ['auto',
#                                                             'randomized']},
#                    scoring='accuracy')

# %%
best_parameters = random_search_pipeline.best_params_
print(best_parameters)
# Out:
# {'pca__svd_solver': 'randomized', 'pca__n_components': 2, 'logistic__penalty': 'l2', 'logistic__max_iter': 1197}

# %%
random_search_pipeline.best_score_
# Out:
# 0.6796319156099202

# %% [markdown]
# #### Exercise 1: apply hyperparameter search to pokemon dataset optimization

# %%
pokemon_df = pd.read_csv('Pokemon.csv')
pokemon_df['HighStage'] = pokemon_df['Stage'] > 2
pokemon_df['Bin_HighStage'] = pokemon_df['HighStage'].apply(lambda x: 1 if x == True else 0)

# %%
# iterating the columns 
pok_feature_names = []
for col in pokemon_df.columns: 
    pok_feature_names.append(str(col))
pok_feature_names[1:-1]
# Out:
# ['Name',
#  'Type_1',
#  'Type_2',
#  'Total',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp_Atk',
#  'Sp_Def',
#  'Speed',
#  'Stage',
#  'Legendary',
#  'HighStage']

# %%
pokemon_df = pokemon_df.drop(pok_feature_names[1:4], axis=1)
pokemon_df = pokemon_df.drop(['Legendary', 'Stage', 'HighStage'], axis=1)
pokemon_df
# Out:
#        #  Total   HP  Attack  Defense  Sp_Atk  Sp_Def  Speed  Bin_HighStage
# 0      1    318   45      49       49      65      65     45              0
# 1      2    405   60      62       63      80      80     60              0
# 2      3    525   80      82       83     100     100     80              1
# 3      4    309   39      52       43      60      50     65              0
# 4      5    405   58      64       58      80      65     80              0
# ..   ...    ...  ...     ...      ...     ...     ...    ...            ...
# 146  147    300   41      64       45      50      50     50              0
# 147  148    420   61      84       65      70      70     70              0
# 148  149    600   91     134       95     100     100     80              1
# 149  150    680  106     110       90     154      90    130              0
# 150  151    600  100     100      100     100     100    100              0
#
# [151 rows x 9 columns]

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(
    pokemon_df.drop('Bin_HighStage', axis=1),
    pokemon_df['Bin_HighStage'])

# %%
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from scipy import stats


pca = PCA()
logistic = LogisticRegression(max_iter=10000, tol=0.1)
pipe = Pipeline(steps=[('pca', pca), ('logistic', logistic)])

# %%
param_distribution = {
    'n_estimators': stats.poisson(300),
    'criterion': ['gini', 'entropy'],
    'bootstrap': [True, False],
    'max_depth': stats.binom(10,0.3)
}

# %%
random_search_classifier_2 = model_selection.RandomizedSearchCV(estimator=classifier,
                     param_distributions = param_distribution,
                     n_iter=30,
                     scoring='accuracy',
                     cv=5,
                     n_jobs=-1)

# %%
feat_names = \
['Total',
 'HP',
 'Attack',
 'Defense',
 'Sp_Atk',
 'Sp_Def',
 'Speed']

# %%
# %%time
random_search_classifier_2.fit(X_train[feat_names],y_train)
# Out:
# CPU times: user 714 ms, sys: 14.5 ms, total: 728 ms
# Wall time: 7.39 s
# RandomizedSearchCV(cv=5,
#                    estimator=RandomForestClassifier(n_estimators=300,
#                                                     random_state=0),
#                    n_iter=30, n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'criterion': ['gini', 'entropy'],
#                                         'max_depth': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f714143d278>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f714143df28>},
#                    scoring='accuracy')

# %%
best_parameters = random_search_classifier_2.best_params_
print(best_parameters)
# Out:
# {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 6, 'n_estimators': 318}

# %%
random_search_classifier_2.best_score_
# Out:
# 0.8936758893280633
