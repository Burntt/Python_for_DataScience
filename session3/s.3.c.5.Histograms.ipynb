# %% [markdown]
# #### General imports

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns

from bokeh.io import output_file, output_notebook
from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource
from bokeh.layouts import row, column, gridplot
from bokeh.models.widgets import Tabs, Panel

# %%
pokemon_df = pd.read_csv('https://raw.githubusercontent.com/ObozniyMaksym/HS_data/main/Pokemon_m.csv')

# %%
pokemon_source = ColumnDataSource(pokemon_df)
output_notebook()

# %% [markdown]
# #### Agregate pokemon data on Type 1

# %%
pokemon_type_1_stats_df = pokemon_df.groupby('Type_1').mean().reset_index()
pokemon_type_1_stats_df
# Out:
#       Type_1           #       Total  ...      Speed     Stage  Legendary
# 0        Bug   42.916667  336.250000  ...  57.083333  1.666667   0.000000
# 1     Dragon  148.000000  440.000000  ...  66.666667  2.000000   0.000000
# 2   Electric   91.111111  444.444444  ...  98.888889  1.444444   0.111111
# 3      Fairy   35.500000  403.000000  ...  47.500000  1.500000   0.000000
# 4   Fighting   75.285714  412.142857  ...  66.142857  1.571429   0.000000
# 5       Fire   64.166667  455.583333  ...  84.000000  1.583333   0.083333
# 6      Ghost   93.000000  405.000000  ...  95.000000  2.000000   0.000000
# 7      Grass   55.583333  409.416667  ...  52.083333  1.833333   0.000000
# 8     Ground   73.500000  374.375000  ...  58.125000  1.500000   0.000000
# 9        Ice  134.000000  517.500000  ...  90.000000  1.000000   0.500000
# 10    Normal   71.727273  380.409091  ...  69.318182  1.363636   0.000000
# 11    Poison   51.071429  383.500000  ...  58.785714  1.714286   0.000000
# ...

# %% [markdown]
# #### Pandas

# %%
pokemon_type_1_stats_df['HP']
# Out:
# 0     55.416667
# 1     64.333333
# 2     54.444444
# 3     82.500000
# 4     63.571429
# 5     63.833333
# 6     45.000000
# 7     65.000000
# 8     58.125000
# 9     77.500000
# 10    78.681818
# 11    64.500000
# 12    63.875000
# 13    53.888889
# 14    64.535714
# Name: HP, dtype: float64

# %%
type(pokemon_type_1_stats_df['HP'])
# Out:
# pandas.core.series.Series

# %%
pokemon_type_1_stats_df['HP'].plot(kind = 'hist')

# %%
pokemon_df['HP'].plot(kind = 'hist')

# %% [markdown]
# #### Matplotlib

# %%
plt.hist( pokemon_type_1_stats_df['HP'])
# Out:
# (array([1., 0., 3., 1., 1., 6., 0., 0., 2., 1.]),
#  array([45.  , 48.75, 52.5 , 56.25, 60.  , 63.75, 67.5 , 71.25, 75.  ,
#         78.75, 82.5 ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# #### Seaborn

# %%
sns.distplot(pokemon_type_1_stats_df['HP'])
# Out:
# /opt/Anaconda3-5.2.0-Linux-x86_64/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(pokemon_df['HP'])
# Out:
# /opt/Anaconda3-5.2.0-Linux-x86_64/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### Excercise 5.1: Draw a histogram for unaggregated pokemon df HP in matplotlib, sns and bokeh

# %%
pokemon_df['HP'].plot(kind = 'hist')

# %%
plt.hist(pokemon_df['HP'])
# Out:
# (array([11., 51., 61., 21.,  2.,  3.,  1.,  0.,  0.,  1.]),
#  array([ 10.,  34.,  58.,  82., 106., 130., 154., 178., 202., 226., 250.]),
#  <a list of 10 Patch objects>)

# %%
sns.distplot(pokemon_df['HP'])
# Out:
# /opt/Anaconda3-5.2.0-Linux-x86_64/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### Exercise 5.2: Aggreagte pokemon data on Type 2 and draw histograms

# %% [markdown]
# #### Distribution

# %%
pokemon_df.drop('Stage', axis =1).plot(kind = 'density')

# %%
pokemon_df.drop(['Stage','Total'], axis =1).plot(kind = 'density')

# %%
pokemon_df['HP'].plot(kind = 'density')

# %%
sns.distplot(pokemon_df['Total'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
pokemon_df['Total'].mean()
# Out:
# 407.0794701986755

# %%
pokemon_df['Total'].std()
# Out:
# 99.74384012250637

# %%
pokemon_df['Total'].plot(kind = 'density')

# %%
sns.distplot(pokemon_df['Total'])
# Out:
# /opt/Anaconda3-5.2.0-Linux-x86_64/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### Excercise 5.3: Draw a distribution plot for Attack and Defense in matplotlib and sns
