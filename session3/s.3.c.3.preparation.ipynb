# %% [markdown]
# #### General imports

# %%
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-baf368f80de7> in <module>
# ----> 1 import pandas as pd
#       2 import numpy as np
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# #### Plotting libraries

# %% [markdown]
# https://matplotlib.org/

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# https://seaborn.pydata.org/

# %%
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-a84c0541e888> in <module>
# ----> 1 import seaborn as sns
#
# ~/.local/lib/python3.6/site-packages/seaborn/__init__.py in <module>
#       4
#       5 # Import seaborn objects
# ----> 6 from .rcmod import *
#       7 from .utils import *
#       8 from .palettes import *
#
# ~/.local/lib/python3.6/site-packages/seaborn/rcmod.py in <module>
#       3 import functools
#       4 import matplotlib as mpl
# ----> 5 from . import palettes, _orig_rc_params
#       6
#       7
#
# ~/.local/lib/python3.6/site-packages/seaborn/palettes.py in <module>
#      10 from .external.six.moves import range
#      11
# ---> 12 from .utils import desaturate, set_hls_values, get_color_cycle
#      13 from .colors import xkcd_rgb, crayons
#      14
#
# ~/.local/lib/python3.6/site-packages/seaborn/utils.py in <module>
#       5
#       6 import numpy as np
# ----> 7 from scipy import stats
#       8 import pandas as pd
#       9 import matplotlib as mpl
#
# ModuleNotFoundError: No module named 'scipy'

# %%
from bokeh.io import output_file, output_notebook
from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource
from bokeh.layouts import row, column, gridplot
from bokeh.models.widgets import Tabs, Panel

# %% [markdown]
# #### Excercise 3.1: Read Pokemon_m

# %%
pokemon_df = pd.read_csv('Pokemon_m.csv', index_col=0, encoding='utf-8')
pokemon_df
# Out:
#            Name   Type_1  Type_2  Total   HP  Attack  Defense  Sp_Atk  Sp_Def  \
# #
# 1     Bulbasaur    Grass  Poison    318   45      49       49      65      65
# 2       Ivysaur    Grass  Poison    405   60      62       63      80      80
# 3      Venusaur    Grass  Poison    525   80      82       83     100     100
# 4    Charmander     Fire     NaN    309   39      52       43      60      50
# 5    Charmeleon     Fire     NaN    405   58      64       58      80      65
# ..          ...      ...     ...    ...  ...     ...      ...     ...     ...
# 147     Dratini   Dragon     NaN    300   41      64       45      50      50
# 148   Dragonair   Dragon     NaN    420   61      84       65      70      70
# 149   Dragonite   Dragon  Flying    600   91     134       95     100     100
# 150      Mewtwo  Psychic     NaN    680  106     110       90     154      90
# 151         Mew  Psychic     NaN    600  100     100      100     100     100
#
#      Speed  Stage  Legendary
# #
# 1       45      1      False
# 2       60      2      False
# 3       80      3      False
# 4       65      1      False
# 5       80      2      False
# ..     ...    ...        ...
# 147     50      1      False
# 148     70      2      False
# 149     80      3      False
# 150    130      1       True
# 151    100      1      False
#
# [151 rows x 12 columns]

# %%
# %store pokemon_df
# Out:
# Stored 'pokemon_df' (DataFrame)

# %% [markdown]
# #### Exercise 3.2: Organize bokeh source for pokemon dataset

# %%
pokemon_source = ColumnDataSource(pokemon_df)

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1003">Loading BokehJS ...</span>
#     </div>
