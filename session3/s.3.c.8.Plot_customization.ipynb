# %% [markdown]
# #### General imports

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns

from bokeh.io import output_file, output_notebook
from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource
from bokeh.layouts import row, column, gridplot
from bokeh.models.widgets import Tabs, Panel

# %%
# %store -r pokemon_df

# %%
# %store -r pokemon_type_1_stats_df

# %%
pokemon_df
# Out:
#            Name    Type_1   Type_2  Total   HP  Attack  Defense  Sp_Atk  \
# #
# 1     Bulbasaur     Grass   Poison    318   45      49       49      65
# 2       Ivysaur     Grass   Poison    405   60      62       63      80
# 3      Venusaur     Grass   Poison    525   80      82       83     100
# 4    Charmander      Fire      NaN    309   39      52       43      60
# 5    Charmeleon      Fire      NaN    405   58      64       58      80
# 6     Charizard      Fire   Flying    534   78      84       78     109
# 7      Squirtle     Water      NaN    314   44      48       65      50
# 8     Wartortle     Water      NaN    405   59      63       80      65
# 9     Blastoise     Water      NaN    530   79      83      100      85
# 10     Caterpie       Bug      NaN    195   45      30       35      20
# 11      Metapod       Bug      NaN    205   50      20       55      25
# 12   Butterfree       Bug   Flying    395   60      45       50      90
# ...

# %%
pokemon_source = ColumnDataSource(pokemon_df)
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3b43d2cc-6816-4db8-ba51-9e77f04485f7">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# #### Excercise 8.1: Draw a lection axis and legend control plots

# %%
plt.scatter('Attack', 'Defense', data = pokemon_df)
plt.title('Pokemon Atac, Pokemon Defenc')

plt.xlim([0, 700])
plt.ylabel('Defense')
plt.xlabel('Attack')

plt.show()
# Out:
# Text(0.5,0,'Attack')

# %%
fig, ax = plt.subplots()
pokemon_type_1_stats_df.plot(kind='barh', 
                             y="HP", 
                             x="Type_1", 
                             ax=ax)
ax.set_xlim([0, 100])
ax.set_xlabel('Health Points')
ax.set_ylabel('Pokemon type')
plt.show()

# %%
fig, ax = plt.subplots()
pokemon_df.plot(kind = 'scatter',
                x = 'Attack',
               y = 'Defense',
               ax = ax,
               label = 'Pokemon Attack/Defense pair')

ax.set_xlabel('Attack ~~~')
ax.set_ylabel('Defense ~~~')
ax.legend()
plt.show(fig)

# %%
fig

# %%
plt.scatter('Attack', 'Defense', data = pokemon_df)
plt.title('Pokemon Atac, Pokemon Defenc')
plt.legend(["Attack/Defense pair"])
plt.ylabel('Defense')
plt.xlabel('Attack')
plt.show()

# %% [markdown]
# #### Excercise 8.2: Draw a plot for Sp_Atk and Sp_Def in matplotlib with both working methods and sns

# %%
sns.scatterplot(x='Sp_Atk', y = 'Sp_Def', data=pokemon_df).set_title("SP Attack/Def Pair")

# %%
plt.scatter('Sp_Atk', 'Sp_Def', data=pokemon_df)
plt.title('Pokemon Sp Atac, Pokemon Defenc')
plt.legend(["SP Attack/Defense pair"])
plt.ylabel('SP Defense')
plt.xlabel('SP Attack')
plt.show()

# %%
fig, ax = plt.subplots()
pokemon_df.plot(kind = 'scatter',
                x = 'Sp_Atk',
               y = 'Sp_Def',
               ax = ax,
               label = 'Pokemon SP Attack/Defense pair')

ax.set_xlabel('SP Attack ~~~')
ax.set_ylabel('SP Defense ~~~')
ax.legend()
plt.show(fig)

# %% [markdown]
# #### Excercise 14: Draw a text control plots

# %%
plt.scatter('Attack', 'Defense', data = pokemon_df)
plt.text(0,175,'.This is (0,175)')
plt.text(120,0,'.This is (120,0)')
plt.text(120,175,'.This is (120,175)')
plt.text(0,0,'.This is (0,0)')
plt.show()

# %% [markdown]
# #### Excercise 15: Draw a text for Sp_Atk and Sp_Def scatterplot in matplotlib

# %%
plt.scatter('Sp_Atk', 'Sp_Def', data=pokemon_df)
plt.title('Pokemon Sp Atac, Pokemon Defenc')
plt.legend(["SP Attack/Defense pair"])
plt.ylabel('SP Defense')
plt.xlabel('SP Attack')
plt.text(70, 105, 'Random text')
plt.show()

# %% [markdown]
# #### Excercise 16: Draw a palette control plots

# %%
sns.lmplot(x='Attack', y='Defense', data=pokemon_df,
           fit_reg=False, hue = 'Type_2')

# %%
sns.lmplot(x='Attack', y='Defense', data=pokemon_df,
           fit_reg=False, hue = 'Type_1')

# %% [markdown]
# #### Excercise 17: Draw a controleed palette for Sp_Atk and Sp_Def scatterplot in matplotlib

# %%
sns.lmplot(x='Sp_Atk', y='Sp_Def', data=pokemon_df,
           fit_reg=False, hue = 'Type_1')

# %%
sns.lmplot(x='Sp_Atk', y='Sp_Def', data=pokemon_df,
           fit_reg=False, hue = 'Type_2')
