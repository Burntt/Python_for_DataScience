# %%
# imports

# pandas
import pandas as pd
from pandas import Series,DataFrame

# %% [markdown]
# #### Exercise 1: Download the dataset

# %% [markdown]
# https://www.kaggle.com/kavita5/twitter-dataset-avengersendgame/download

# %% [markdown]
# #### Exercise 2:
# Create Target column from retweetCount > np.median[retweetCount]
# Create dataset in .csv file with new features along with .yaml file with it's descritpion, median[retweetCount] value stored in retweetCount_median variable, preferably store data in data folder

# %%
tweets_df = pd.read_csv('tweets.csv', encoding='cp1252')
tweets_df
# Out:
#        Unnamed: 0                                               text  \
# 0               1  RT @mrvelstan: literally nobody:\r\nme:\r\n\r\...
# 1               2  RT @agntecarter: i’m emotional, sorry!!\r\n\r\...
# 2               3  saving these bingo cards for tomorrow \r\n©\r\...
# 3               4  RT @HelloBoon: Man these #AvengersEndgame ads ...
# 4               5  RT @Marvel: We salute you, @ChrisEvans! #Capta...
# 5               6  RT @MCU_Direct: The first NON-SPOILER #Avenger...
# 6               7  RT @Renner4Real: Ready to rock  !   #excited #...
# 7               8  RT @Avengers: We’re with him ‘til the end of t...
# 8               9  RT @Variety: #AvengersEndgame first reactions:...
# 9              10  RT @HelloBoon: Man these #AvengersEndgame ads ...
# 10             11  RT @Avengers: Destiny has arrived, Josh Brolin...
# 11             12  RT @Marvel: We salute you, @ChrisEvans! #Capta...
# 12             13  RT @itsjustanx: Scarlett Johansson and Brie La...
# 13             14  RT @softerstark: heyy y'all please share these...
# 14             15  RT @pottermcu: first and last public event of ...
# 15             16  RT @nesserwd: Boy... These two fuckers will be...
# 16             17  RT @Avengers: We salute you, @ChrisEvans! #Cap...
# 17             18  RT @spiderthcr: Chris Hemsworth with his wife ...
# 18             19  RT @_PVRCinemas: <U+0001F4E2> #ContestAlert #A...
# 19             20  RT @HelloBoon: Man these #AvengersEndgame ads ...
# 20             21  RT @EW: See all the stars at the #AvengersEndg...
# 21             22  RT @Paytm: Get ready for #AvengersEndgame\r\n\...
# 22             23  RT @targrycn: honestly chris evans saying he c...
# 23             24  RT @FunkoEurope: Born leaders <U+270C><U+FE0F>...
# 24             25  RT @Marvel: The red carpet’s a-buzz with @Evan...
# 25             26  RT @Marvel: We’re here at the World Premiere o...
# 26             27  RT @dchrisevans: He came to the wrong Avenger....
# 27             28  RT @Razer: We’re in the Endgame now—who’s watc...
# 28             29  Still not emotionally prepared for #AvengersEn...
# 29             30  RT @Avengers: Whatever it takes. We are LIVE f...
# ...           ...                                                ...
# 14970       14971  RT @_saker_falcon: SEBASTIAN STAN STANS \r\n\r...
# 14971       14972  RT @NikkieTutorials: reason number 7241 why to...
# 14972       14973  RT @Avengers: Destiny has arrived, Josh Brolin...
# 14973       14974  RT @tonysthetic: eternal love for her please #...
# 14974       14975  RT @Marvel: .@wongrel, with a magical arrival!...
# 14975       14976  Soft porn <U+0001F60F><U+0001F602> #AvengersEn...
# 14976       14977  Brie Larson with some #InfinityGauntlet inspir...
# 14977       14978  Excited much for tomorrow! Watching at 8AM #Av...
# 14978       14979  RT @OriginalFunko: RT &amp; follow @OriginalFu...
# 14979       14980  I'm like this today, only replace Santa with E...
# 14980       14981  RT @ashchanchlani: After party #AvengersEndGam...
# 14981       14982  RT @natportman_news: Natalie has attended the ...
# 14982       14983  Not long now! Tomorrow’s double bill of Infini...
# 14978      False              0         NaN  2019-04-23 09:22:08      False
# 14979      False              0         NaN  2019-04-23 09:22:07      False
# 14980      False              0         NaN  2019-04-23 09:22:07      False
# 14981      False              0         NaN  2019-04-23 09:22:07      False
# 14982      False              0         NaN  2019-04-23 09:22:07      False
# 14983      False              0         NaN  2019-04-23 09:22:06      False
# 14984      False              0         NaN  2019-04-23 09:22:06      False
# 14985      False              0         NaN  2019-04-23 09:22:06      False
# 14986      False              0         NaN  2019-04-23 09:22:05      False
# 14987      False              0         NaN  2019-04-23 09:22:05      False
# 14988      False              0         NaN  2019-04-23 09:22:05      False
# 14989      False              1   TicketNew  2019-04-23 09:22:04       True
# 14990      False              0         NaN  2019-04-23 09:22:04      False
# 14991      False              0         NaN  2019-04-23 09:22:04      False
# 14992      False              0         NaN  2019-04-23 09:22:04      False
# 14993      False              0         NaN  2019-04-23 09:22:03      False
# 14994      False              0         NaN  2019-04-23 09:22:03      False
# 14995      False              0         NaN  2019-04-23 09:22:03      False
# 14996      False              0         NaN  2019-04-23 09:22:03      False
# 14997      False              0  SPICinemas  2019-04-23 09:22:02      False
# 14998      False              0         NaN  2019-04-23 09:22:02      False
# 14999      False              0         NaN  2019-04-23 09:22:01      False
#
#          replyToSID                   id   replyToUID  \
# 0               NaN  1120639328034676737          NaN
# 1               NaN  1120639325199196160          NaN
# 2               NaN  1120639324683292674          NaN
# 3               NaN  1120639323328540672          NaN
# 4               NaN  1120639321571074048          NaN
# 5               NaN  1120639319952318464          NaN
# 6               NaN  1120639318685515780          NaN
# 7               NaN  1120639315975921664          NaN
# 8               NaN  1120639313417523200          NaN
# 9               NaN  1120639309533437952          NaN
# 10              NaN  1120639308266975233          NaN
# 11              NaN  1120639306748583937          NaN
# 12              NaN  1120639305188294656          NaN
# 13              NaN  1120639305062309888          NaN
# 14              NaN  1120639304596746240          NaN
# 15              NaN  1120639303929999360          NaN
# 16              NaN  1120639302604480513          NaN
# 17              NaN  1120639301900034049          NaN
# 18              NaN  1120639301895774209          NaN
# 19              NaN  1120639301664985089          NaN
# 20              NaN  1120639299345629185          NaN
# 21              NaN  1120639299207061504          NaN
# 22              NaN  1120639298712113152          NaN
# 23              NaN  1120639298297061376          NaN
# 24              NaN  1120639297508577280          NaN
# 25              NaN  1120639295579148289          NaN
# 26              NaN  1120639295105175555          NaN
# 27              NaN  1120639294815731712          NaN
# 28              NaN  1120639292731052032          NaN
# 29              NaN  1120639292613832704          NaN
# ...             ...                  ...          ...
# 14970           NaN  1120618860082810882          NaN
# 14971           NaN  1120618856895197184          NaN
# 14972           NaN  1120618856416808961          NaN
# 14973           NaN  1120618852981837825          NaN
# 14974           NaN  1120618852398899200          NaN
# 14975           NaN  1120618851304132609          NaN
# 14976  1.120601e+18  1120618850280775680   60144333.0
# 14977           NaN  1120618849638866944          NaN
# 14978           NaN  1120618849236410368          NaN
# 14979           NaN  1120618847143436288          NaN
# 14980           NaN  1120618846291886080          NaN
# 14981           NaN  1120618844035473408          NaN
# 14982           NaN  1120618843930529793          NaN
# 14983           NaN  1120618841216667648          NaN
# 14984           NaN  1120618840637837312          NaN
# 14985           NaN  1120618839895490560          NaN
# 14986           NaN  1120618836263178241          NaN
# 14987           NaN  1120618835562967040          NaN
# 14982  <a href="http://twitter.com/download/iphone" r...   SpencerSmith74
# 14983  <a href="http://twitter.com/download/android" ...    OMG_its_Ashya
# 14984  <a href="http://twitter.com/download/android" ...     AbazHurairah
# 14985  <a href="http://twitter.com/download/android" ...   Dheajuliasari2
# 14986  <a href="http://twitter.com/download/android" ...      greabryelle
# 14987  <a href="http://twitter.com/download/iphone" r...    Killer_sach14
# 14988  <a href="http://twitter.com/download/android" ...         711Prabu
# 14989  <a href="http://twitter.com/download/android" ...    VishalGehani3
# 14990  <a href="http://twitter.com/download/iphone" r...      _thorsbruce
# 14991  <a href="http://twitter.com/download/iphone" r...      CassieFlouf
# 14992  <a href="http://twitter.com/download/android" ...      albertojs99
# 14993  <a href="http://twitter.com/download/iphone" r...      aditi__1989
# 14994  <a href="http://twitter.com/download/android" ...   MrWellintynSEP
# 14995  <a href="http://twitter.com/download/android" ...        tommysboi
# 14996  <a href="http://twitter.com/download/iphone" r...  kimberleywithae
# 14997  <a href="http://twitter.com/download/android" ...       Gnanavel07
# 14998  <a href="https://mobile.twitter.com" rel="nofo...       _moonljght
# 14999  <a href="http://twitter.com/download/android" ...  CaterinaCabrel1
#
#        retweetCount  isRetweet  retweeted  longitude  latitude
# 0               637       True      False        NaN       NaN
# 1               302       True      False        NaN       NaN
# 2                 0      False      False        NaN       NaN
# 3             23781       True      False        NaN       NaN
# 4             13067       True      False        NaN       NaN
# 5              3122       True      False        NaN       NaN
# 6               269       True      False        NaN       NaN
# 7              5687       True      False        NaN       NaN
# 8               349       True      False        NaN       NaN
# 9             23781       True      False        NaN       NaN
# 10             4164       True      False        NaN       NaN
# 11            13067       True      False        NaN       NaN
# 12             1409       True      False        NaN       NaN
# 13                8       True      False        NaN       NaN
# 14               54       True      False        NaN       NaN
# 15              443       True      False        NaN       NaN
# 16            13320       True      False        NaN       NaN
# 17                3       True      False        NaN       NaN
# 18              331       True      False        NaN       NaN
# 19            23781       True      False        NaN       NaN
# 20               81       True      False        NaN       NaN
# 21            25884       True      False        NaN       NaN
# 22             1041       True      False        NaN       NaN
# 23               14       True      False        NaN       NaN
# 24             2099       True      False        NaN       NaN
# 25             1326       True      False        NaN       NaN
# 26               13       True      False        NaN       NaN
# 27              157       True      False        NaN       NaN
# 28                0      False      False        NaN       NaN
# 29             9264       True      False        NaN       NaN
# ...             ...        ...        ...        ...       ...
# 14970            42       True      False        NaN       NaN
# 14971          2851       True      False        NaN       NaN
# 14972          4200       True      False        NaN       NaN
# 14973            11       True      False        NaN       NaN
# 14974          1634       True      False        NaN       NaN
# 14975             3      False      False        NaN       NaN
# 14976             0      False      False        NaN       NaN
# 14977             0      False      False        NaN       NaN
# 14978         18600       True      False        NaN       NaN
# 14979             0      False      False        NaN       NaN
# 14980           164       True      False        NaN       NaN
# 14981             1       True      False        NaN       NaN
# 14982             0      False      False        NaN       NaN
# 14983           430       True      False        NaN       NaN
# 14984         24662       True      False        NaN       NaN
# 14985          1766       True      False        NaN       NaN
# 14986         14453       True      False        NaN       NaN
# 14987         24662       True      False        NaN       NaN
# 14988         13167       True      False        NaN       NaN
# 14989             1      False      False        NaN       NaN
# 14990           268       True      False        NaN       NaN
# 14991          2851       True      False        NaN       NaN
# 14992          3742       True      False        NaN       NaN
# 14993           536       True      False        NaN       NaN
# 14994           507       True      False        NaN       NaN
# 14995            33       True      False        NaN       NaN
# 14996          2307       True      False        NaN       NaN
# 14997             0      False      False        NaN       NaN
# 14998         13167       True      False        NaN       NaN
# 14999         10736       True      False        NaN       NaN
#
# [15000 rows x 17 columns]

# %% [markdown]
# #### Exercise 3: Collaborate at github account
#
# https://github.com/maxmmsu/harbour.space.DS.402
#
# Create an .md file in it with the table of participants (one for a group), select a short acronim for your name (e.g. Maxim Musin --> mm) and write down the acronim to the table.

# %% [markdown]
# #### Exercise 4: Сreate a folder with your first exeperimet, name it exp_[your name acronim]_1, make it a python package, organize all transformers and classifiers wih python modules and .yaml files.

# %% [markdown]
# #### Exercise 5: Select one of the following feature creation technics, write it down to collaboration table
#
# ##### Step 1 create 3 of the following features
# - Extract lenght of the sentence
# - Extract number of words
# - Extract number of characters
# - Extract number of hastags
#
# - Create a dummy variable for RT at the beginning of the twit
# - Creatu dummy variable from first letter of twit being A, B, C or D
#
# ##### Step 2 preform polynomial feature generation with parameter k = 2..6
#
# ##### Step 3 perform dimensionality reduction to limit number of vatiables
# - perform PCA dimensionality reduction
# - *prefromr PCA dimensionality reduction according to covered variance
# - select features with maximum mutual information with target variable
# - *select features according to sum of adjusted mutual info score

# %% [markdown]
# #### Exercise 6: Extract names of avengers endgame characters from text
#
# Examples of tags in quetion:
# #Thanos
# #WinterSoldier
# #CaptainAmerica
# #blackwidow
# #CaptainMarvel
# #Mantis
#
# store the resulting dataset in data folder with .yaml description, preferable naming for variable names is lowercase name of the tag

# %% [markdown]
# #### Exercise 7: Create set of classifiers for linear regression with different features for feature generation.
# use the following methods of feature generation
#
#  - word tokenization with 1-gram, f
#  - pos tokenization with extraction of all NP
#  - pos tokenization with 2-gram bag of tokens for all NNP
#  - 2-gram bag of characters for screenName features
#  - polynomial features for presence of avenger character names
#
# Organize classes of transformers in various .py files

# %% [markdown]
# #### Exercise 8: Apply PCA dimensionality reduction and LogisticRegression to predict Target, construct pipelines for all transformers from Exercise 5 and 7 (name them exp_[your name acronim]\_6_1, ... exp_[your name acronim]\_6_...) implement them as custom classifiers.

# %% [markdown]
# #### Exercise 9: Split dataset to train and test (it is up to you which features you will include in it) and store it data folder along with .yaml description

# %% [markdown]
# #### Exercise 10: Add intialization from .yaml descriptions of classifiers to implementations of classifiers at Exercise 7.

# %% [markdown]
# #### Exercise 11: Train classifiers with various PCA dimensionality, bag of words and polynomial paramters paramteres on train, test them on test and store in .yaml files for every experiment with resulting metrics
#
# - accuracy
# - precision
# - recall
# - adjusted_mutual_information

# %% [markdown]
# #### Exercise 12*: Read urls on dataset follow them with the following example, download attached images and count people on them with cv features

# %% [markdown]
# #### Exercise 13*: Add new features to all PCA output on Exercise 6, train classifiers, test quality and store results in proper .yaml files

# %% [markdown]
# #### Exercise 14*: Perform topic modelings on text feature, add it to PCA features from Exercise 8, train classifiers, test quality and store results in proper .yaml files

# %% [markdown]
# #### Exercise 15: Combine all combinations of features from Exercise 8, measure the results of improvement of classifier

# %% [markdown]
# #### Exercise 16*: For 5 best of prevous experiments, change LinearRegression to XGBClassifier. Try several XGB configurations, store results and parameters in .yaml files

# %% [markdown]
# #### Exercise 17: in collaboration with classmates create the best possible classifier for the data using various technics
