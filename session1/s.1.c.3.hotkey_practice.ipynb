# %% [markdown]
# ## Hotkey practice

# %% [markdown]
# ### Ubuntu and windows important hotkeys
#
# ![Hotkeys ubuntu windowns](hotkeys_ubuntu_and_windows.png)
#
# ### Mac important hotkeys
#
# ![Hotkeys mac](hotkeys_mac_1.png)
#
# ![Hotkeys mac](hotkeys_mac_2.png)
#
# ![Hotkeys mac](hotkeys_mac_3.png)

# %% [markdown]
# #### Exercise 2.1: Spit cell

# %%
param_set = {'iterations':10,
            'subiterations':100}

# %%
for i in range(param_set['iterations']):
    for j in range(param_set['subiterations']):
        pass

# %% [markdown]
# #### Exercise 2.2: Sort rows manually with C and V commands

# %% [markdown]
# 00 w

# %% [markdown]
# 07 n

# %% [markdown]
# 01 e

# %% [markdown]
# 05 d

# %% [markdown]
# 02 l

# %% [markdown]
# 03 l

# %% [markdown]
# 06 o

# %% [markdown]
# 04

# %% [markdown]
# 08 e

# %% [markdown]
# #### Exercise 2.3: Merge resulting rows in one

# %% [markdown]
# #### Exercise 2.4: delete empty rows

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
