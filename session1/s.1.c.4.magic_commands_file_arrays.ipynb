# %% [markdown]
# ## Reading text data with juyter magic commands

# %%
# !ls
# Out:
# sample_data

# %%
# !ls alice*
# Out:
# ls: cannot access 'alice*': No such file or directory

# %%
list_of_files = !ls alice*

# %%
list_of_files
# Out:
# ['alice_00.txt',
#  'alice_01.txt',
#  'alice_02.txt',
#  'alice_03.txt',
#  'alice_04.txt',
#  'alice_05.txt',
#  'alice_06.txt',
#  'alice_07.txt',
#  'alice_08.txt']

# %%
number_of_alice_quote = 4
string_number_of_alice_quote = "%.2d" % number_of_alice_quote
string_number_of_alice_quote
# Out:
# '04'

# %%
# !ls alice_$string_number_of_alice_quote*
# Out:
# alice_04.txt

# %%
# !cat alice_$string_number_of_alice_quote*
# Out:
# “But it’s no use now,” thought poor Alice, “to pretend to be two people! Why, there’s hardly enough of me left to make one respectable person!”

# %%
# !cat alice_$string_number_of_alice_quote* | grep Alice
# Out:
# “But it’s no use now,” thought poor Alice, “to pretend to be two people! Why, there’s hardly enough of me left to make one respectable person!”

# %% [markdown]
# ##### windows version

# %%
# !dir alice_$string_number_of_alice_quote*
# need some additional modification

# %%
# !type alice_$string_number_of_alice_quote*

# %% [markdown]
# #### Exercise 3.1: Read files with Alice quotes to array

# %% [markdown]
# #### Exercise 3.2: Modify the code so only non single line citations will be present

# %% [markdown]
# #### Exercise 3.3. Use grep console function select only lines with Alice string present
