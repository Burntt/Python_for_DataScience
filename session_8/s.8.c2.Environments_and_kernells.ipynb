# %% [markdown]
# #### Exercise 2.1: Create dummy environment in your server. Name it with your name

# %%
# !pwd
# Out:
# /home/ubuntu/Berend_Gort/session_8

# %%
# !ls
# Out:
# Berend_Python3_env		   s.8.c2.Environments_and_kernells.ipynb
# Kernel_Venv_Python3_Example.ipynb  s.8.c3.Git_Practice.ipynb
# create_eth_file.eth		   textgenrnn
# ls_output.out			   vim_writefile_from_terminal
# s.8.c.1.Unix_basics.ipynb

# %%
# !cd Berend_Python3_env
# !ls

# cant seem to cd into the environment folder?
# Out:
# Berend_Python3_env		   s.8.c2.Environments_and_kernells.ipynb
# Kernel_Venv_Python3_Example.ipynb  s.8.c3.Git_Practice.ipynb
# create_eth_file.eth		   textgenrnn
# ls_output.out			   vim_writefile_from_terminal
# s.8.c.1.Unix_basics.ipynb

# %% [markdown]
# #### Exercise 2.2: install pandas pandas version 0.21.1 in your virtual environment

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '0.21.1'

# %% [markdown]
# #### Exercise 2.3: create custom kernel for jupyter with your virtual environment

# %% [markdown]
# /.local/share/jupyter/kernels/berend_python3_env

# %% [markdown]
# {
#  "argv": [
#   "/home/ubuntu/Berend_Gort/session_8/Berend_Python3_env/bin/python",
#   "-m",
#   "ipykernel_launcher",
#   "-f",
#   "{connection_file}"
#  ],
#  "display_name": "Berend_Python3_env",
#  "language": "python"
# }

# %% [markdown]
# #### Exercise 2.4: switch current notebook kernel to your kernel

# %% [markdown]
# See top right :)

# %% [markdown]
# #### Exercise 2.5: test pandas version

# %%
import pandas as pd
pd.__version__
# Out:
# '0.21.1'

# %% [markdown]
# #### Exercise 2.6: Install xgboost, tensorflow and torch packages to your environment with pip

# %% [markdown]
# pip install xgboost
# pip install tensorflow
# pip install torch

# %% [markdown]
# #### Exercise 2.7: test they are working

# %%
from xgboost import XGBClassifier
import tensorflow as tf
import torch

dir(XGBClassifier)
dir(tf)
dir(torch)
# Out:
# ['AVG',
#  'AggregationType',
#  'AnyType',
#  'Argument',
#  'ArgumentSpec',
#  'Assert',
#  'BFloat16Storage',
#  'BFloat16Tensor',
#  'BenchmarkConfig',
#  'BenchmarkExecutionStats',
#  'Block',
#  'BoolStorage',
#  'BoolTensor',
#  'BoolType',
#  'BufferDict',
#  'ByteStorage',
#  'ByteTensor',
#  'CONV_BN_FUSION',
#  'CallStack',
#  'Capsule',
#  'CharStorage',
#  'CharTensor',
#  'ClassType',
#  'Code',
#  'CompilationUnit',
#  'CompleteArgumentSpec',
#  'ComplexDoubleStorage',
#  'ComplexFloatStorage',
#  'ConcreteModuleType',
#  'ConcreteModuleTypeBuilder',
#  'CudaBFloat16StorageBase',
#  'CudaBoolStorageBase',
#  'CudaByteStorageBase',
#  'CudaCharStorageBase',
#  'CudaComplexDoubleStorageBase',
#  'CudaComplexFloatStorageBase',
#  'CudaDoubleStorageBase',
#  'CudaFloatStorageBase',
#  'CudaHalfStorageBase',
#  'CudaIntStorageBase',
#  'CudaLongStorageBase',
#  'CudaShortStorageBase',
#  'DeepCopyMemoTable',
#  'DeviceObjType',
#  'DictType',
#  'DisableTorchFunction',
# ...

# %% [markdown]
# #### Exercise 2.8: Clone and install repo

# %% [markdown]
# https://github.com/minimaxir/textgenrnn

# %% [markdown]
# Clone comand:

# %% [markdown]
# git clone https://github.com/minimaxir/textgenrnn.git

# %% [raw]
# installaction command inside virtualenv:
#
# python3 setup.py

# %% [raw]
# pip install tqdm for textgenrnn

# %%
from textgenrnn import textgenrnn

dir(textgenrnn)
# Out:
# ['META_TOKEN',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'config',
#  'default_config',
#  'encode_text_vectors',
#  'generate',
#  'generate_samples',
#  'generate_to_file',
#  'load',
#  'reset',
#  'save',
#  'similarity',
#  'train_from_file',
#  'train_from_largetext_file',
#  'train_new_model',
#  'train_on_texts']
