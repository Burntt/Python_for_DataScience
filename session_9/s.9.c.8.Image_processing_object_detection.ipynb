# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

# %% [markdown]
# ### Working with images with OpenCV

# %% [markdown]
# ![Apple](apple.jpeg )

# %%
im = cv2.imread('apple.jpeg')

# %%
im
# Out:
# array([[[  1, 135, 117],
#         [  0, 134, 116],
#         [  4, 135, 115],
#         ...,
#         [157, 168, 200],
#         [153, 164, 196],
#         [150, 161, 193]],
#
#        [[  0, 133, 115],
#         [  0, 132, 115],
#         [  2, 133, 113],
#         ...,
#         [155, 166, 198],
#         [151, 162, 194],
#         [148, 159, 191]],
#
#        [[  0, 131, 114],
#         [  0, 131, 114],
#         [  1, 132, 112],
#         ...,
#         [152, 163, 193],
#         [148, 159, 189],
#         [145, 156, 186]],
#
#        ...,
#
#        [[153, 213, 213],
#         [154, 214, 214],
#         [154, 214, 214],
#         ...,
#         [ 24,  62,  40],
#         [ 22,  60,  38],
#         [ 22,  60,  38]],
#
#        [[153, 213, 213],
#         [153, 213, 213],
#         [154, 214, 214],
#         ...,
#         [ 23,  61,  39],
#         [ 22,  60,  38],
#         [ 24,  62,  40]],
#
#        [[153, 213, 213],
#         [153, 213, 213],
#         [153, 213, 213],
#         ...,
#         [ 22,  60,  38],
#         [ 23,  61,  39],
#         [ 25,  63,  41]]], dtype=uint8)

# %%
type(im)
# Out:
# numpy.ndarray

# %%
np.apply_along_axis(np.mean, 2, im)
# Out:
# array([[ 84.33333333,  83.33333333,  84.66666667, ..., 175.        ,
#         171.        , 168.        ],
#        [ 82.66666667,  82.33333333,  82.66666667, ..., 173.        ,
#         169.        , 166.        ],
#        [ 81.66666667,  81.66666667,  81.66666667, ..., 169.33333333,
#         165.33333333, 162.33333333],
#        ...,
#        [193.        , 194.        , 194.        , ...,  42.        ,
#          40.        ,  40.        ],
#        [193.        , 193.        , 194.        , ...,  41.        ,
#          40.        ,  42.        ],
#        [193.        , 193.        , 193.        , ...,  40.        ,
#          41.        ,  43.        ]])

# %%
np.apply_over_axes(np.mean, im, (0,1))
# Out:
# array([[[ 60.36981074, 102.58832804, 109.86737951]]])

# %%
im.shape
# Out:
# (768, 1024, 3)

# %%
plt.imshow(im)

# %%
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(im)

# %%
np.apply_over_axes(np.mean, im, (0,1))
# Out:
# array([[[109.86737951, 102.58832804,  60.36981074]]])

# %%
import cvlib

# %%
bbox, label, conf = cvlib.detect_common_objects(im)

# %%
bbox
# Out:
# []

# %%
label
# Out:
# []

# %%
conf
# Out:
# []

# %%
out_im = np.array(im)

# %%
output_image = cvlib.object_detection.draw_bbox(out_im, bbox, label, conf)
plt.imshow(output_image)

# %%
one_bbox = bbox[-1]
one_bbox
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-50-9300d35dc678> in <module>
# ----> 1 one_bbox = bbox[-1]
#       2 one_bbox
#
# IndexError: list index out of range

# %%
box_coordinates = np.array(one_bbox).reshape( (2,2) ).transpose()
box_coordinates
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-e4c9704f014c> in <module>
# ----> 1 box_coordinates = np.array(one_bbox).reshape( (2,2) ).transpose()
#       2 box_coordinates
#
# NameError: name 'one_bbox' is not defined

# %%
subimage = im[ one_bbox[1]:one_bbox[3], one_bbox[0]:one_bbox[2]]
plt.imshow(subimage)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-5f64cf8caf78> in <module>
# ----> 1 subimage = im[ one_bbox[1]:one_bbox[3], one_bbox[0]:one_bbox[2]]
#       2 plt.imshow(subimage)
#
# NameError: name 'one_bbox' is not defined

# %%
resized_image = cv2.resize(subimage, (128,128))
plt.imshow(resized_image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-a49f649fb213> in <module>
# ----> 1 resized_image = cv2.resize(subimage, (128,128))
#       2 plt.imshow(resized_image)
#
# NameError: name 'subimage' is not defined

# %%
plt.imshow(out_im)

# %%
plt.imsave('apple_processed.png', out_im)

# %%
cv2.imwrite('apple_processed.png', im)
# Out:
# True

# %% [markdown]
# ![Apple processed](apple_processed.png)
