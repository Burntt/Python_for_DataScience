# %%
import pandas as pd

# %% [markdown]
# #### Exercis 3.2: loading titanic_m_ df from the store

# %%
titanic_m_df = pd.read_csv('https://raw.githubusercontent.com/ObozniyMaksym/HS_data/main/titanic_m.csv', index_col=0)

# %%
titanic_m_df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 17             1         0       3  ...   7.2500   NaN         S
# 18             2         1       1  ...  71.2833   C85         C
# 19             3         1       3  ...   7.9250   NaN         S
# 20             4         1       1  ...  53.1000  C123         S
# 21             5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 903          887         0       2  ...  13.0000   NaN         S
# 904          888         1       1  ...  30.0000   B42         S
# 905          889         0       3  ...  23.4500   NaN         S
# 906          890         1       1  ...  30.0000  C148         C
# 907          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %% [markdown]
# #### Exercise 3.3: Change part of the selection

# %%
titanic_m_df.loc[17:25,['Age','Sex']]
# Out:
#      Age     Sex
# 17  22.0    male
# 18  38.0  female
# 19  26.0  female
# 20  35.0  female
# 21  35.0    male
# 22   NaN    male
# 23  54.0    male
# 24   2.0    male
# 25  27.0  female

# %%
titanic_m_df.loc[17:25,['Age','Sex']] = 'dazdranagon'

titanic_m_df
# Out:
#      PassengerId  Survived  Pclass  \
# 17             1         0       3
# 18             2         1       1
# 19             3         1       3
# 20             4         1       1
# 21             5         0       3
# ..           ...       ...     ...
# 903          887         0       2
# 904          888         1       1
# 905          889         0       3
# 906          890         1       1
# 907          891         0       3
#
#                                                   Name          Sex  \
# 17                             Braund, Mr. Owen Harris  dazdranagon
# 18   Cumings, Mrs. John Bradley (Florence Briggs Th...  dazdranagon
# 19                              Heikkinen, Miss. Laina  dazdranagon
# 20        Futrelle, Mrs. Jacques Heath (Lily May Peel)  dazdranagon
# 21                            Allen, Mr. William Henry  dazdranagon
# ..                                                 ...          ...
# ...

# %%
titanic_m_df.iloc[0:2,3:5]= 'harbour.space'

titanic_m_df
# Out:
#      PassengerId  Survived  Pclass  \
# 17             1         0       3
# 18             2         1       1
# 19             3         1       3
# 20             4         1       1
# 21             5         0       3
# ..           ...       ...     ...
# 903          887         0       2
# 904          888         1       1
# 905          889         0       3
# 906          890         1       1
# 907          891         0       3
#
#                                              Name            Sex   Age  SibSp  \
# 17                                  harbour.space  harbour.space  22.0      1
# 18                                  harbour.space  harbour.space  38.0      1
# 19                                    dazdranagon    dazdranagon  26.0      0
# 20   Futrelle, Mrs. Jacques Heath (Lily May Peel)         female  35.0      1
# 21                       Allen, Mr. William Henry           male  35.0      0
# ...
