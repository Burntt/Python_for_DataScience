# %%
import pandas as pd

# %%
titanic_m_df = pd.read_csv('https://raw.githubusercontent.com/ObozniyMaksym/HS_data/main/titanic_m.csv', index_col=0)

# %%
titanic_m_df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 17             1         0       3  ...   7.2500   NaN         S
# 18             2         1       1  ...  71.2833   C85         C
# 19             3         1       3  ...   7.9250   NaN         S
# 20             4         1       1  ...  53.1000  C123         S
# 21             5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 903          887         0       2  ...  13.0000   NaN         S
# 904          888         1       1  ...  30.0000   B42         S
# 905          889         0       3  ...  23.4500   NaN         S
# 906          890         1       1  ...  30.0000  C148         C
# 907          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %% [markdown]
# #### Exercise 4.1: Perform selection query both ways

# %%
titanic_m_df.query('Age > 20 and SibSp == 1')
# Out:
#      PassengerId  Survived  Pclass  ...      Fare Cabin  Embarked
# 17             1         0       3  ...    7.2500   NaN         S
# 18             2         1       1  ...   71.2833   C85         C
# 20             4         1       1  ...   53.1000  C123         S
# 30            14         0       3  ...   31.2750   NaN         S
# 35            19         0       3  ...   18.0000   NaN         S
# ..           ...       ...     ...  ...       ...   ...       ...
# 873          857         1       1  ...  164.8667   NaN         S
# 878          862         0       2  ...   11.5000   NaN         S
# 883          867         1       2  ...   13.8583   NaN         C
# 888          872         1       1  ...   52.5542   D35         S
# 891          875         1       2  ...   24.0000   NaN         C
#
# [136 rows x 12 columns]

# %%
titanic_m_df.loc[(titanic_m_df.Age > 20) & (titanic_m_df.SibSp == 1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 17             1         0       3
# 18             2         1       1
# 20             4         1       1
# 30            14         0       3
# 35            19         0       3
# ..           ...       ...     ...
# 873          857         1       1
# 878          862         0       2
# 883          867         1       2
# 888          872         1       1
# 891          875         1       2
#
#                                                   Name            Sex   Age  \
# 17                                       harbour.space  harbour.space  22.0
# 18                                       harbour.space  harbour.space  38.0
# 20        Futrelle, Mrs. Jacques Heath (Lily May Peel)         female  35.0
# 30                         Andersson, Mr. Anders Johan           male  39.0
# 35   Vander Planke, Mrs. Julius (Emelia Maria Vande...         female  31.0
# ..                                                 ...            ...   ...
# ...

# %% [markdown]
# #### Exercise 4.2: Change age for all male pasengers of titanic to +1 year

# %%
titanic_m_df.loc[(titanic_m_df.Sex == 'male'), 'Age'] +=1

titanic_m_df
# Out:
#      PassengerId  Survived  Pclass  \
# 17             1         0       3
# 18             2         1       1
# 19             3         1       3
# 20             4         1       1
# 21             5         0       3
# ..           ...       ...     ...
# 903          887         0       2
# 904          888         1       1
# 905          889         0       3
# 906          890         1       1
# 907          891         0       3
#
#                                              Name            Sex   Age  SibSp  \
# 17                                  harbour.space  harbour.space  22.0      1
# 18                                  harbour.space  harbour.space  38.0      1
# 19                                    dazdranagon    dazdranagon  26.0      0
# 20   Futrelle, Mrs. Jacques Heath (Lily May Peel)         female  35.0      1
# 21                       Allen, Mr. William Henry           male  39.0      0
# ...
