# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

from PIL import Image

# %% [markdown]
# #### Exercise 8.1: Reading image to numpy array

# %%
image_object = Image.open('image_example.png')
image_object
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=214x278 at 0x7F6A8AAE9B70>

# %%
np.asarray( image_object)
# Out:
# array([[[214, 212, 191],
#         [213, 210, 190],
#         [211, 208, 189],
#         ...,
#         [ 82, 120, 141],
#         [  0,   0,   0],
#         [  0,   0,   0]],
#
#        [[215, 213, 192],
#         [213, 211, 191],
#         [213, 210, 190],
#         ...,
#         [ 83, 121, 142],
#         [  0,   0,   0],
#         [  0,   0,   0]],
#
#        [[216, 213, 192],
#         [214, 212, 191],
#         [213, 211, 190],
#         ...,
#         [ 84, 122, 143],
#         [  0,   0,   0],
#         [  0,   0,   0]],
#
#        ...,
#
#        [[ 14,  40,  59],
#         [ 14,  40,  59],
#         [ 14,  40,  59],
#         ...,
#         [111,  94,  73],
#         [  0,   0,   0],
#         [  0,   0,   0]],
#
#        [[ 14,  40,  59],
#         [ 14,  40,  59],
#         [ 14,  40,  59],
#         ...,
#         [ 85,  70,  56],
#         [  0,   0,   0],
#         [  0,   0,   0]],
#
#        [[ 14,  40,  59],
#         [ 14,  40,  59],
#         [ 14,  40,  59],
# ...

# %%
image_np = np.array(np.asarray( image_object))
image_np
# Out:
# array([[[214, 212, 191],
#         [213, 210, 190],
#         [211, 208, 189],
#         ...,
#         [ 82, 120, 141],
#         [  0,   0,   0],
#         [  0,   0,   0]],
#
#        [[215, 213, 192],
#         [213, 211, 191],
#         [213, 210, 190],
#         ...,
#         [ 83, 121, 142],
#         [  0,   0,   0],
#         [  0,   0,   0]],
#
#        [[216, 213, 192],
#         [214, 212, 191],
#         [213, 211, 190],
#         ...,
#         [ 84, 122, 143],
#         [  0,   0,   0],
#         [  0,   0,   0]],
#
#        ...,
#
#        [[ 14,  40,  59],
#         [ 14,  40,  59],
#         [ 14,  40,  59],
#         ...,
#         [111,  94,  73],
#         [  0,   0,   0],
#         [  0,   0,   0]],
#
#        [[ 14,  40,  59],
#         [ 14,  40,  59],
#         [ 14,  40,  59],
#         ...,
#         [ 85,  70,  56],
#         [  0,   0,   0],
#         [  0,   0,   0]],
#
#        [[ 14,  40,  59],
#         [ 14,  40,  59],
#         [ 14,  40,  59],
# ...

# %%
# %store image_np 
# %store image_object
# Out:
# Stored 'image_np' (ndarray)
# Stored 'image_object' (PngImageFile)

# %%
# %store -r image_np

# %%
type(image_np)
# Out:
# numpy.ndarray

# %%
image_np.shape
# Out:
# (278, 214, 3)

# %%
image_np[0,0]
# Out:
# array([214, 212, 191], dtype=uint8)

# %% [markdown]
# array([RED, GREEN, BLUE], dtype=uint8)

# %%
image_np[0,0] = [0,0,0]

# %%
image_np[0,0,:] = [0,0,0]

# %%
Image.fromarray(image_np)
# Out:
# <PIL.Image.Image image mode=RGB size=214x278 at 0x7F6A8AAE9710>

# %% [markdown]
# #### Exercise 8.2 Painting square to black

# %%
image_np[0:20,0:20,:] = [0,0,0]

# %%
image_np[0:20,0:20,:2] = [0,0]

# %%
image_np[0:20,0:20,:2] = 0

# %%
image_np[0:20,0:20,:2] = np.zeros((20,20,2))

# %%
np.zeros((20,20,2)).shape
# Out:
# (20, 20, 2)

# %%
Image.fromarray(image_np)
# Out:
# <PIL.Image.Image image mode=RGB size=214x278 at 0x7F6A8AA7D438>

# %%
image_np[0:20,0:20,:]
# Out:
# array([[[  0,   0, 191],
#         [  0,   0, 190],
#         [  0,   0, 189],
#         ...,
#         [  0,   0, 179],
#         [  0,   0, 178],
#         [  0,   0, 177]],
#
#        [[  0,   0, 192],
#         [  0,   0, 191],
#         [  0,   0, 190],
#         ...,
#         [  0,   0, 179],
#         [  0,   0, 178],
#         [  0,   0, 178]],
#
#        [[  0,   0, 192],
#         [  0,   0, 191],
#         [  0,   0, 190],
#         ...,
#         [  0,   0, 179],
#         [  0,   0, 179],
#         [  0,   0, 178]],
#
#        ...,
#
#        [[  0,   0, 204],
#         [  0,   0, 203],
#         [  0,   0, 202],
#         ...,
#         [  0,   0, 190],
#         [  0,   0, 189],
#         [  0,   0, 188]],
#
#        [[  0,   0, 204],
#         [  0,   0, 204],
#         [  0,   0, 203],
#         ...,
#         [  0,   0, 191],
#         [  0,   0, 190],
#         [  0,   0, 189]],
#
#        [[  0,   0, 204],
#         [  0,   0, 204],
#         [  0,   0, 204],
# ...

# %% [markdown]
# #### Exercise 8.3: Painting line to pink

# %% [markdown]
# How to google RGB code for pink
# https://www.google.com/search?q=rgb+code+for+pink&oq=RGB+code+for+pink&aqs=chrome.0.0l6.11182j0j7&sourceid=chrome&ie=UTF-8

# %%
image_np[:,0:20,:] = [255,192,203]

# %%
Image.fromarray(image_np)
# Out:
# <PIL.Image.Image image mode=RGB size=214x278 at 0x7F6A8AA7D7B8>

# %%
image_np
# Out:
# array([[[255, 192, 203],
#         [255, 192, 203],
#         [255, 192, 203],
#         ...,
#         [ 82, 120, 141],
#         [  0,   0,   0],
#         [  0,   0,   0]],
#
#        [[255, 192, 203],
#         [255, 192, 203],
#         [255, 192, 203],
#         ...,
#         [ 83, 121, 142],
#         [  0,   0,   0],
#         [  0,   0,   0]],
#
#        [[255, 192, 203],
#         [255, 192, 203],
#         [255, 192, 203],
#         ...,
#         [ 84, 122, 143],
#         [  0,   0,   0],
#         [  0,   0,   0]],
#
#        ...,
#
#        [[255, 192, 203],
#         [255, 192, 203],
#         [255, 192, 203],
#         ...,
#         [111,  94,  73],
#         [  0,   0,   0],
#         [  0,   0,   0]],
#
#        [[255, 192, 203],
#         [255, 192, 203],
#         [255, 192, 203],
#         ...,
#         [ 85,  70,  56],
#         [  0,   0,   0],
#         [  0,   0,   0]],
#
#        [[255, 192, 203],
#         [255, 192, 203],
#         [255, 192, 203],
# ...

# %% [markdown]
# #### Exercise 8.4: Painting a row in blue

# %%
image_np[20:30,20:,:] = [0,255,255]

# %%
Image.fromarray(image_np)
# Out:
# <PIL.Image.Image image mode=RGB size=214x278 at 0x7F6A8AA7D358>

# %%
image_np
# Out:
# array([[[255, 192, 203],
#         [255, 192, 203],
#         [255, 192, 203],
#         ...,
#         [ 82, 120, 141],
#         [  0,   0,   0],
#         [  0,   0,   0]],
#
#        [[255, 192, 203],
#         [255, 192, 203],
#         [255, 192, 203],
#         ...,
#         [ 83, 121, 142],
#         [  0,   0,   0],
#         [  0,   0,   0]],
#
#        [[255, 192, 203],
#         [255, 192, 203],
#         [255, 192, 203],
#         ...,
#         [ 84, 122, 143],
#         [  0,   0,   0],
#         [  0,   0,   0]],
#
#        ...,
#
#        [[255, 192, 203],
#         [255, 192, 203],
#         [255, 192, 203],
#         ...,
#         [111,  94,  73],
#         [  0,   0,   0],
#         [  0,   0,   0]],
#
#        [[255, 192, 203],
#         [255, 192, 203],
#         [255, 192, 203],
#         ...,
#         [ 85,  70,  56],
#         [  0,   0,   0],
#         [  0,   0,   0]],
#
#        [[255, 192, 203],
#         [255, 192, 203],
#         [255, 192, 203],
# ...

# %%
image_np[20:30, :, :]
# Out:
# array([[[255, 192, 203],
#         [255, 192, 203],
#         [255, 192, 203],
#         ...,
#         [  0, 255, 255],
#         [  0, 255, 255],
#         [  0, 255, 255]],
#
#        [[255, 192, 203],
#         [255, 192, 203],
#         [255, 192, 203],
#         ...,
#         [  0, 255, 255],
#         [  0, 255, 255],
#         [  0, 255, 255]],
#
#        [[255, 192, 203],
#         [255, 192, 203],
#         [255, 192, 203],
#         ...,
#         [  0, 255, 255],
#         [  0, 255, 255],
#         [  0, 255, 255]],
#
#        ...,
#
#        [[255, 192, 203],
#         [255, 192, 203],
#         [255, 192, 203],
#         ...,
#         [  0, 255, 255],
#         [  0, 255, 255],
#         [  0, 255, 255]],
#
#        [[255, 192, 203],
#         [255, 192, 203],
#         [255, 192, 203],
#         ...,
#         [  0, 255, 255],
#         [  0, 255, 255],
#         [  0, 255, 255]],
#
#        [[255, 192, 203],
#         [255, 192, 203],
#         [255, 192, 203],
# ...

# %%
type(image_np[20:30, :,:])

# %%
image_np[20:30, :,:].shape
# Out:
# (10, 214, 3)

# %% [markdown]
# #### Exercise 8.5 switching red and blue channels

# %%
image_np[:,:,0]
# Out:
# array([[255, 255, 255, ...,  82,   0,   0],
#        [255, 255, 255, ...,  83,   0,   0],
#        [255, 255, 255, ...,  84,   0,   0],
#        ...,
#        [255, 255, 255, ..., 111,   0,   0],
#        [255, 255, 255, ...,  85,   0,   0],
#        [255, 255, 255, ..., 108,   0,   0]], dtype=uint8)

# %%
image_np[:,:,0].shape
# Out:
# (278, 214)

# %%
plt.imshow(image_np[:,:,0], cmap='gray')
plt.show()

# %%
plt.imshow(image_np[:,:,2], cmap='gray')
plt.show()

# %%
image_np[:,:,[0,2]].shape
# Out:
# (278, 214, 2)

# %%
image_np[:,:,[0,2]]
# Out:
# array([[[255, 203],
#         [255, 203],
#         [255, 203],
#         ...,
#         [ 82, 141],
#         [  0,   0],
#         [  0,   0]],
#
#        [[255, 203],
#         [255, 203],
#         [255, 203],
#         ...,
#         [ 83, 142],
#         [  0,   0],
#         [  0,   0]],
#
#        [[255, 203],
#         [255, 203],
#         [255, 203],
#         ...,
#         [ 84, 143],
#         [  0,   0],
#         [  0,   0]],
#
#        ...,
#
#        [[255, 203],
#         [255, 203],
#         [255, 203],
#         ...,
#         [111,  73],
#         [  0,   0],
#         [  0,   0]],
#
#        [[255, 203],
#         [255, 203],
#         [255, 203],
#         ...,
#         [ 85,  56],
#         [  0,   0],
#         [  0,   0]],
#
#        [[255, 203],
#         [255, 203],
#         [255, 203],
#         ...,
#         [108,  73],
#         [  0,   0],
#         [  0,   0]]], dtype=uint8)

# %%
image_np[:,:,[2,0]] = image_np[:,:,[0,2]]

# %%
plt.imshow(image_np)
plt.show()

# %% [markdown]
# #### Exercise 8.6 Using pandas for explanatory purposes

# %%
import pandas as pd

# %%
titanic_df = pd.read_csv("titanic_m.csv")
titanic_df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0            17            1         0       3
# 1            18            2         1       1
# 2            19            3         1       3
# 3            20            4         1       1
# 4            21            5         0       3
# ..          ...          ...       ...     ...
# 886         903          887         0       2
# 887         904          888         1       1
# 888         905          889         0       3
# 889         906          890         1       1
# 890         907          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
titanic_df['Fare'][titanic_df['Sex'] == 'male' ] = 42
# Out:
# /home/maxmmsu/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
titanic_df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0            17            1         0       3
# 1            18            2         1       1
# 2            19            3         1       3
# 3            20            4         1       1
# 4            21            5         0       3
# ..          ...          ...       ...     ...
# 886         903          887         0       2
# 887         904          888         1       1
# 888         905          889         0       3
# 889         906          890         1       1
# 890         907          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
titanic_df['Fare'][titanic_df['Age'] > 30 ] = 15
# Out:
# /home/maxmmsu/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
titanic_df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0            17            1         0       3
# 1            18            2         1       1
# 2            19            3         1       3
# 3            20            4         1       1
# 4            21            5         0       3
# ..          ...          ...       ...     ...
# 886         903          887         0       2
# 887         904          888         1       1
# 888         905          889         0       3
# 889         906          890         1       1
# 890         907          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %% [markdown]
# #### Returning to numpy

# %%
image_np[:,:,2] > 256 - 64
# Out:
# array([[ True,  True,  True, ..., False, False, False],
#        [ True,  True,  True, ..., False, False, False],
#        [ True,  True,  True, ..., False, False, False],
#        ...,
#        [ True,  True,  True, ..., False, False, False],
#        [ True,  True,  True, ..., False, False, False],
#        [ True,  True,  True, ..., False, False, False]])

# %%
image_np[ image_np[:,:,2] > 256 - 64 ] = 0

# %%
plt.imshow(image_np)
plt.show()

# %%
image_np[ image_np[:,:,2] > 128 ] = 0

# %%
plt.imshow(image_np)
plt.show()

# %%
image_np[ image_np[:,:,2] > 128 ]
# Out:
# array([], shape=(0, 3), dtype=uint8)
